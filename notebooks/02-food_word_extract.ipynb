# %%
# Imports
import pandas as pd
import numpy as np
import spacy
import json
import re
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
#import tqdm
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
#from tqdm import tqdm


plt.style.use('ggplot')
# %matplotlib inline

# %%
df_1 = pd.read_parquet('file/yelp_foods_mentioned.parquet')
df_1.head(10)
# Out:
#               id  stars  useful  funny  cool  \
# 1251197  2980811    4.0       0      0     0
# 197231    467079    4.0      12      3     7
# 226443    543661    1.0       3      0     0
# 263340    638958    5.0       4      2     4
# 151897    352283    5.0       1      0     2
# 2306988  5523173    5.0       0      0     0
# 1354912  3227020    5.0       1      0     1
# 1679076  4020477    4.0       7      0     1
# 27814      63876    1.0       1      1     0
# 1893515  4523556    5.0       0      0     0
#
#                                                       text  \
# 1251197  we landed at the reno airport for our honeymoo...
# 197231   this atmosphere is certainly geared towards am...
# 226443   food and service are key components to enjoy a...
# 263340   cyranos is a hidden gem that i wish i had know...
# 151897   wow kekes truly impressed me this afternoon  m...
# 2306988  its quite a drive to sparks but there are only...
# 1354912  my husband and i visited this location for lun...
# 1679076  finally stopped by here after getting tired of...
# 27814    i went here for lunch after an extremely cold ...
# 1893515  called and ordered the chicken tikka pizza  es...
#
#          sentiment.negative  sentiment.neutral  sentiment.positive  \
# 1251197            0.030769           0.244984            0.724247
# 197231             0.032657           0.175753            0.791589
# 226443             0.891778           0.097133            0.011089
# 263340             0.002409           0.013464            0.984127
# 151897             0.002309           0.009757            0.987934
# 2306988            0.001669           0.025890            0.972441
# 1354912            0.005359           0.015456            0.979185
# 1679076            0.012973           0.136857            0.850170
# 27814              0.937443           0.056307            0.006250
# 1893515            0.007335           0.073568            0.919097
#
#                                             food mentioned
# 1251197  [pizza, egg, beef, cake, coffee, tea, pancake,...
# 197231            [pork, shrimp, ribs, bbq, ramen, potato]
# 226443                                     [rice, dessert]
# 263340        [rice, bread, crab, cake, dessert, cocktail]
# 151897                                               [egg]
# 2306988                               [soup, pie, falafel]
# 1354912          [steak, salad, cheese, shrimp, tea, taco]
# 1679076  [chicken, fish, salad, rice, bread, egg, pork,...
# 27814                               [soup, sandwich, meat]
# 1893515                                   [pizza, chicken]

# %%
# Use idxmax to find the column with the maximum value in each row
df_1['sentiment'] = df_1[['sentiment.negative', 'sentiment.neutral', 'sentiment.positive']].idxmax(axis=1)

# To remove the 'sentiment.' prefix and keep only the sentiment name
df_1['sentiment'] = df_1['sentiment'].str.replace('sentiment.', '')

# If you want to add an 'id' column as well (assuming it doesn't already exist)
df_1.reset_index(inplace=True)
df_1.rename(columns={'index': 'id_review'}, inplace=True)

# Show the new dataframe structure
df_1.head(10)
# Out:
#    id_review       id       id  stars  useful  funny  cool  \
# 0          0  1251197  2980811    4.0       0      0     0
# 1          1   197231   467079    4.0      12      3     7
# 2          2   226443   543661    1.0       3      0     0
# 3          3   263340   638958    5.0       4      2     4
# 4          4   151897   352283    5.0       1      0     2
# 5          5  2306988  5523173    5.0       0      0     0
# 6          6  1354912  3227020    5.0       1      0     1
# 7          7  1679076  4020477    4.0       7      0     1
# 8          8    27814    63876    1.0       1      1     0
# 9          9  1893515  4523556    5.0       0      0     0
#
#                                                 text  sentiment.negative  \
# 0  we landed at the reno airport for our honeymoo...            0.030769
# 1  this atmosphere is certainly geared towards am...            0.032657
# 2  food and service are key components to enjoy a...            0.891778
# 3  cyranos is a hidden gem that i wish i had know...            0.002409
# 4  wow kekes truly impressed me this afternoon  m...            0.002309
# 5  its quite a drive to sparks but there are only...            0.001669
# 6  my husband and i visited this location for lun...            0.005359
# 7  finally stopped by here after getting tired of...            0.012973
# 8  i went here for lunch after an extremely cold ...            0.937443
# 9  called and ordered the chicken tikka pizza  es...            0.007335
#
#    sentiment.neutral  sentiment.positive  \
# 0           0.244984            0.724247
# 1           0.175753            0.791589
# 2           0.097133            0.011089
# 3           0.013464            0.984127
# 4           0.009757            0.987934
# 5           0.025890            0.972441
# 6           0.015456            0.979185
# 7           0.136857            0.850170
# 8           0.056307            0.006250
# 9           0.073568            0.919097
#
#                                       food mentioned sentiment
# 0  [pizza, egg, beef, cake, coffee, tea, pancake,...  positive
# 1           [pork, shrimp, ribs, bbq, ramen, potato]  positive
# 2                                    [rice, dessert]  negative
# 3       [rice, bread, crab, cake, dessert, cocktail]  positive
# 4                                              [egg]  positive
# 5                               [soup, pie, falafel]  positive
# 6          [steak, salad, cheese, shrimp, tea, taco]  positive
# 7  [chicken, fish, salad, rice, bread, egg, pork,...  positive
# 8                             [soup, sandwich, meat]  negative
# 9                                   [pizza, chicken]  positive

# %%
df_new = df_1.copy()

# %%
df_new.drop(['sentiment.negative', 'sentiment.neutral', 'sentiment.positive', 'id'], axis=1, inplace=True)

# %%
df_new.head(10)
# Out:
#    id_review  stars  useful  funny  cool  \
# 0          0    4.0       0      0     0
# 1          1    4.0      12      3     7
# 2          2    1.0       3      0     0
# 3          3    5.0       4      2     4
# 4          4    5.0       1      0     2
# 5          5    5.0       0      0     0
# 6          6    5.0       1      0     1
# 7          7    4.0       7      0     1
# 8          8    1.0       1      1     0
# 9          9    5.0       0      0     0
#
#                                                 text  \
# 0  we landed at the reno airport for our honeymoo...
# 1  this atmosphere is certainly geared towards am...
# 2  food and service are key components to enjoy a...
# 3  cyranos is a hidden gem that i wish i had know...
# 4  wow kekes truly impressed me this afternoon  m...
# 5  its quite a drive to sparks but there are only...
# 6  my husband and i visited this location for lun...
# 7  finally stopped by here after getting tired of...
# 8  i went here for lunch after an extremely cold ...
# 9  called and ordered the chicken tikka pizza  es...
#
#                                       food mentioned sentiment
# 0  [pizza, egg, beef, cake, coffee, tea, pancake,...  positive
# 1           [pork, shrimp, ribs, bbq, ramen, potato]  positive
# 2                                    [rice, dessert]  negative
# 3       [rice, bread, crab, cake, dessert, cocktail]  positive
# 4                                              [egg]  positive
# 5                               [soup, pie, falafel]  positive
# 6          [steak, salad, cheese, shrimp, tea, taco]  positive
# 7  [chicken, fish, salad, rice, bread, egg, pork,...  positive
# 8                             [soup, sandwich, meat]  negative
# 9                                   [pizza, chicken]  positive

# %%
df_new.shape
# Out:
# (10000, 8)

# %%
df_1.shape
# Out:
# (10000, 13)

# %%
df_new.to_parquet('yelp_dataset.parquet')
